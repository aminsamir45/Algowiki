# %%
import pandas as pd
import sys

# Go into above directory and download function
sys.path.append('../') 
import sheet_func

# %%
# Extract sheet id - last number
sheet_id = 227713596

df = sheet_func.sheet_to_df(sheet_id)
df
# Out:
#                                     Family Name  Space n = 1000 rate  \
# 0    All Maximal Non-Branching Paths in a Graph                  0.0
# 1                              All Permutations                  1.1
# 2               All-Pairs Shortest Paths (APSP)                  0.0
# 3                       AST to Code Translation                  0.0
# 4                            BCNF Decomposition                  0.0
# ..                                          ...                  ...
# 113                              Tower of Hanoi                  0.0
# 114                Transitive Reduction Problem                  0.0
# 115                            Turnpike Problem                  0.0
# 116                       Variance Calculations                  0.0
# 117                            Voronoi Diagrams                  0.0
#
#      Space n = 10^6 rate  Space n = 10^9 rate  Time n = 1000 rate  \
# 0                    0.0                  0.0             0.00000
# ...

# %%
df_space = df.iloc[:, :4]
df_space
# Out:
#                                     Family Name  Space n = 1000 rate  \
# 0    All Maximal Non-Branching Paths in a Graph                  0.0
# 1                              All Permutations                  1.1
# 2               All-Pairs Shortest Paths (APSP)                  0.0
# 3                       AST to Code Translation                  0.0
# 4                            BCNF Decomposition                  0.0
# ..                                          ...                  ...
# 113                              Tower of Hanoi                  0.0
# 114                Transitive Reduction Problem                  0.0
# 115                            Turnpike Problem                  0.0
# 116                       Variance Calculations                  0.0
# 117                            Voronoi Diagrams                  0.0
#
#      Space n = 10^6 rate  Space n = 10^9 rate
# 0                    0.0                  0.0
# ...

# %%
df_time = df.iloc[:, [0, 4,5,6]]
df_time
# Out:
#                                     Family Name  Time n = 1000 rate  \
# 0    All Maximal Non-Branching Paths in a Graph             0.00000
# 1                              All Permutations             0.00000
# 2               All-Pairs Shortest Paths (APSP)             0.54876
# 3                       AST to Code Translation             0.00000
# 4                            BCNF Decomposition             0.00000
# ..                                          ...                 ...
# 113                              Tower of Hanoi             0.00000
# 114                Transitive Reduction Problem             0.06876
# 115                            Turnpike Problem             0.00000
# 116                       Variance Calculations             0.00000
# 117                            Voronoi Diagrams             0.00000
#
#      Time n = 10^6 rate  Time n = 10^9 rate
# 0              0.000000            0.000000
# 1              0.000000            0.000000
# ...
